# %% [markdown]
# <a href="https://colab.research.google.com/github/rpjena/test_one/blob/master/project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# The first part of the code is to get the credit card rates historical data collected from the FRED database.

# %%
# this is the credit card rates data. Commercial Bank Interest Rate on Credit Card Plans, All Accounts (TERMCBCCALLNS)
df_credit = pd.read_csv('data/TERMCBCCALLNS.csv').set_index('DATE').apply(pd.to_numeric, errors='coerce')
df_credit.index = pd.to_datetime(df_credit.index)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-f64b36c83342> in <cell line: 2>()
#       1 # this is the credit card rates data. Commercial Bank Interest Rate on Credit Card Plans, All Accounts (TERMCBCCALLNS)
# ----> 2 df_credit = pd.read_csv('data/TERMCBCCALLNS.csv').set_index('DATE').apply(pd.to_numeric, errors='coerce')
#       3 df_credit.index = pd.to_datetime(df_credit.index)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
# ...

# %%
df_credit
# Out:
# <Axes: xlabel='DATE'>
